# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import glob, os, json
import matplotlib.pyplot as plt
import corner

import enterprise
from enterprise.pulsar import Pulsar
import enterprise.signals.parameter as parameter
from enterprise.signals import utils
from enterprise.signals import signal_base
from enterprise.signals import selections
from enterprise.signals.selections import Selection
from enterprise.signals import white_signals
from enterprise.signals import gp_signals
from enterprise.signals import deterministic_signals
from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc

# %% [markdown]
# The first step is to load the data. Pulsar timing data is stored as par files, which contain a list of the pulsar's parameters and their uncertainties, and tim files, which contain the pulse times of arrival. Here we initialize all of the pulsar objects from the par and tim files (this will take a while).
#
# In this tutorial, we will only analyze a single pulsar, J1713+0747.

# %%
datadir = './data/'

# %%
parfiles = sorted(glob.glob(datadir + 'J1713*.par'))
timfiles = sorted(glob.glob(datadir + 'J1713*.tim'))

psrs = []
for p, t in zip(parfiles, timfiles):
    psrname = parfiles[0].split('/')[-1].split('_')[0]
    print ('Loading {0}'.format(psrname))
    psr = Pulsar(p, t, ephem='DE436')
    psrs.append(psr)
# Out:
# Loading J1713+0747

# %%
print(enterprise.__version__)
# Out:
# 1.2.0

# %% [markdown]
# First, let's plot the residuals for this pulsar.

# %%
print ('Number of TOAs: {0}'.format(len(psrs[0].toas)))

plt.errorbar(psrs[0].toas, psrs[0].residuals, ls='', marker='.', yerr=psrs[0].toaerrs)

plt.ylabel('Residuals (s)');
plt.xlabel('MJD');

plt.title(psrs[0].name);
# Out:
# Number of TOAs: 27571

# %% [markdown]
# Now, let's construct our signal model, and define which parameters' posteriors we'll be interested in exploring.
#
# First, let's add the white noise. We include three types of white noise: EFAC, which is a linear scaling of the TOA uncertainties; EQUAD, which is white noise added in quadrature to the TOA uncertainties; and ECORR, which is correlated over a single observation but uncorrelated between different observations.
#
# These are nuisance parameters since we aren't interested in searching for a white noise signal. In our analysis, we will fix the white noise to the maximum-likelihood values, which are found from noise analyses run on each pulsar. For now we will initialize the white noise parameters as constants. Later, we will read in the white noise values from a text file.

# %%
# white noise parameters
# here we define them as constants, later we will input the values after the model is initialized
efac = parameter.Constant()
equad = parameter.Constant()
ecorr = parameter.Constant()

# there will be separate white noise parameters for each observing backend
# since NANOGrav began taking data, there have been two generations of backends
# (ASP and PUPPI at Arecibo, GASP and GUPPI at Green Bank)
selection = selections.Selection(selections.by_backend)

# white noise signals
ef = white_signals.MeasurementNoise(efac=efac, selection=selection)
eq = white_signals.EquadNoise(log10_equad=equad, selection=selection)
ec = gp_signals.EcorrBasisModel(log10_ecorr=ecorr, selection=selection)

# %% [markdown]
# Now we add in the red noise. We model the red noise as a power law with two parameters: an amplitude and spectral index, i.e.,
# $$
#     P_{\rm red} = Af^{-\gamma}
# $$

# %%
# red noise parameters
log10_A = parameter.Uniform(-18, -11)
gamma = parameter.Uniform(0, 7)

# define powerlaw PSD and red noise signal
pl = utils.powerlaw(log10_A=log10_A, gamma=gamma)
rn = gp_signals.FourierBasisGP(pl, components=30, name='rn')

# %% [markdown]
# We also include contributions from the pulsar's timing model.

# %%
# linearized timing model
tm = gp_signals.TimingModel(use_svd=False)

# %% [markdown]
# Finally, we include the GW background. I mentioned that we can parameterize the signal in which ever way we want. If we assume the the background is composed for binaries with circular orbits, we can derive the following
#
# $$
# h_{c}^2 \sim f^{-4/3}\int \int \mathrm{d}z \, \mathrm{d}\mathcal{M}\dfrac{\mathrm{d}^2n}{\mathrm{d}z\mathrm{d}\mathcal{M}}\dfrac{1}{(1+z)^{1/3}}\mathcal{M}^{5/3}
# $$
#
# where
#
# $h_{c}$: "characteristic strain"; strength of the stretch and squeeze of space
# <br>
# $f$: gravitational wave frequnecy
# <br>
# $\mathcal{M}$: "chirp mass"; a combination of the total binary mass and mass ratio, i.e., $\mathcal{M} = (m_1 m_2)^{3/5}/(m_1+m_2)^{1/5}$
# <br>
# $z$: redshift
# <br>
# $n$: number density of contributing binaries
#
# We can represent the integral as a frequnecy independent value, $A$ such that
# $$
# h_{c}(f) = Af^{-2/3}.
# $$
#
# We often report the value of A with respect to a gravitational wave frequnecy of 1/year. Then
# $$
# h_{c}(f) = A_{\rm yr}\left(\dfrac{f}{f_{\rm yr}}\right)^{-2/3}.
# $$
#
#
#
# So let's model the background as a power law with fixed spectral index and an amplitude parameter (just like we did for the non-GW red noise!). You can also do runs where you vary the spectral index and the amplitude simultaneously.

# %%
# GW parameters (initialize with names here to use parameters in common across pulsars)
log10_Agw = parameter.LinearExp(-18,-12)('log10_A_gw')
gamma_gw = parameter.Constant(4.33)('gamma_gw')

# gwb (no spatial correlations)
cpl = utils.powerlaw(log10_A=log10_Agw, gamma=gamma_gw)
gwb = gp_signals.FourierBasisGP(spectrum=cpl, components=30, name='gwb')

# %%
# full signal
s = ef + eq + ec + rn + tm + gwb

# %% [markdown]
# I didn't talk about this addition to the signal model, but we uncovered in our analysis a periodic signal which corresponds to an imprecise position for Jupiter. Without properly modeling this erroneous signal, the sampler will mop up its effect on the residuals as part of a GW signal. Since we're only analyzing J1713, we won't include this for now.
#
# (If you revisit this notebook, including more than one pulsar in your analysis, try setting `bayesephem=True` and see how it changes your results.)

# %%
# if you want to include ephemeris modeling, set bayesephem = True
bayesephem = False
if bayesephem:
    s += deterministic_signals.PhysicalEphemerisSignal(use_epoch_toas=True)

# %% [markdown]
# Now we initalize the model and the PTA object.

# %%
# initialize PTA
model = [s(psr) for psr in psrs]
pta = signal_base.PTA(model)

# %% [markdown]
# We get the pulsars' white noise parameters from their noise files.

# %%
# load the white noise parameters from the noisefiles
noisedir = './data/'
noisefiles = glob.glob(noisedir + '*.json')

setpars = {}
for nf in noisefiles:
    with open(nf, 'r') as fin:
        setpars.update(json.load(fin))

# fix the white noise parameters to the values in the noisefiles
pta.set_default_params(setpars)
# Out:
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_ASP_efac to 1.02291
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_PUPPI_efac to 1.08988
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GASP_efac to 1.08451
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GUPPI_efac to 1.04
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GASP_efac to 1.14264
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_efac to 1.06397
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_efac to 1.11373
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_efac to 1.1139
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_ASP_log10_equad to -7.54974
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_PUPPI_log10_equad to -7.89392
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GASP_log10_equad to -7.268
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GUPPI_log10_equad to -8.06696
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GASP_log10_equad to -6.94555
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_log10_equad to -7.14229
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_log10_equad to -7.91342
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_log10_equad to -7.66533
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_L-wide_ASP_log10_ecorr to -6.94671
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_L-wide_PUPPI_log10_ecorr to -7.05341
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_Rcvr1_2_GASP_log10_ecorr to -7.08042
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_Rcvr1_2_GUPPI_log10_ecorr to -7.10529
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_Rcvr_800_GASP_log10_ecorr to -8.09849
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_Rcvr_800_GUPPI_log10_ecorr to -6.6075
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_S-wide_ASP_log10_ecorr to -6.96378
# INFO: enterprise.signals.signal_base: Setting J1713+0747_basis_ecorr_S-wide_PUPPI_log10_ecorr to -7.03281

# %% [markdown]
# Here we draw the initial values for the parameters.
# This model only contains three parameters since we are only analyzing one pulsar, and we are not including BayesEphem. In general, if you run a gravitational wave search with fixed spectral index and without BayesEphem, you will have 2N + 1 parameters, where N is the number of pulsars in the PTA.

# %%
x0 = np.hstack(p.sample() for p in pta.params)
ndim = len(x0)

print (ndim)
# Out:
# 3

# %%
pta.params
# Out:
# [J1713+0747_rn_gamma:Uniform(pmin=0, pmax=7),
#  J1713+0747_rn_log10_A:Uniform(pmin=-18, pmax=-11),
#  log10_A_gw:LinearExp(pmin=-18, pmax=-12)]

# %% [markdown]
# Now that our model is established, as is our starting point for the MCMC, we'll focus on how sampler explores the possible parameter values.
#
# The sampler uses Adaptive Metropolis sampling, which uses the covariance matrix to determine the step sizes for the parameters. We initialize the covariance matrix as a diagonal matrix with the same value in each diagonal element. As the code runs, the covariance matrix will be updated based on the samples in the chain.
#
# We also need to set up parameter groups, which determine which parameters should be jumped in simultaneously. For this run, we only have three groups: one containing all of the parameters, one containing both of the red noise parameters, and one containing the GWB amplitude. In general, the parameters which describe any of our modeled processes are grouped together.

# %%
# initial jump covariance matrix
cov = np.diag(np.ones(ndim) * 0.01**2)

# set up jump groups by red noise groups 
ndim = len(x0)
groups  = [range(0, ndim)]
groups.extend(map(list, zip(range(0,ndim,2), range(1,ndim,2))))
groups.extend([[ndim-1]])
print (groups)
# Out:
# [range(0, 3), [0, 1], [2]]

# %% [markdown]
# Finally, we initialize the sampler object and sample!

# %%
outDir = './chains/'

sampler = ptmcmc(ndim, pta.get_lnlikelihood, pta.get_lnprior, cov, groups=groups, 
                 outDir=outDir, resume=False) # resume=True resumes an unfinished MCMC in your directory

# %%
# write a list of the parameters to a text file
# and a list of the parameter groupings used
filename = outDir + '/params.txt'
np.savetxt(filename,list(map(str, pta.param_names)), fmt='%s')
np.savetxt(outDir + 'groups.txt', groups, fmt='%s')

# %%
# sampler for N steps
# by default, the sampler saves every 10th step in the chain file
N = int(5e3)
x0 = np.hstack(p.sample() for p in pta.params)

sampler.sample(x0, N, SCAMweight=30, AMweight=15, DEweight=50, ) # these weights relate to frequency of jumps
# Out:
# Finished 80.00 percent in 458.041879 s Acceptance rate = 0.334533
# Run Complete

# %% [markdown]
# Now that it has run for a while, let's take a look at the chains.
#
# The chain contains the parameter values in the same order as in the params.txt file. The last four columns are the log-probability, the log-likelihood, the acceptance rate, and the parallel tempering acceptance rate (since we are not using parallel tempering, the last column will just be 1.)

# %%
chain = np.loadtxt('chains/chain_1.txt')
params = list(np.loadtxt('chains/params.txt', dtype='S42'))

# %%
plt.plot(chain[:,params.index(b'log10_A_gw')]);
plt.ylabel('log10_A_gw');

# %% [markdown]
# We calculate the 95% upper limit on the GWB from this pulsar below. For comparison, the upper limit from the whole 11-year data set is $A_\mathrm{gw} = 1.45 \times 10^{-15}$.

# %%
burn = int(0.25*chain.shape[0])

plt.hist(chain[burn:,params.index(b'log10_A_gw')], histtype='step', bins=50);
plt.xlabel('log10_A_gw');

ul = np.percentile(chain[burn:, params.index(b'log10_A_gw')], q=95)
plt.axvline(ul, ls='--')
print(10**ul)
# Out:
# 1.3964072060867878e-13

# %% [markdown]
# Finally, let's take a look at the posteriors for all of the parameters in our model. You will notice that J1713+0747 does not have significant red noise.

# %%
corner.corner(chain[burn:,:-4], labels=params,smooth=0.5,plot_datapoints=False,plot_density=True,plot_contours=False,fill_contours=False);
